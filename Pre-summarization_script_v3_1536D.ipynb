# %%
# This is pre-summary generation notebook v1.1, as the previous version worked but generated 129k summaries. Additionally, this version generates summaries of 1000 words instaed of 
# 500 words, so we can inspect the difference in quality and nuance of ideas. 
# V2: changed the vector dimensions to 1536 to match requirements later in the pipeline

# %%
import os
import pickle
import json
import boto3
import logging
import yaml
import pandas as pd
import numpy as np
from datetime import datetime
from typing import Dict, List, Any, Union
from tqdm import tqdm
from openai import OpenAI
from pinecone import Pinecone
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer

# ---------- Configure Logging ----------
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler('topic_summarization.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

# ---------- Config ----------
class Config:
    def __init__(self, config_file="config.yaml", summary_words=500):
        # Load configuration from YAML file
        self.config_data = self.load_config(config_file)
        
        # File paths
        self.CLUSTERED_VECTORS_PATH = "rizzbot_data/cleaned_clustered_vectors.pkl"
        self.TOPIC_MODEL_PATH = "rizzbot_data/bertopic_model"
        
        # S3 settings
        self.S3_BUCKET = "rizzbot-temp-storage"
        self.S3_PREFIX = "rizzbot/Summaries/"
        
        # Pinecone settings
        self.PINECONE_INDEX = "rizzbot-summaries"
        
        # Model settings
        self.EMBEDDING_MODEL = "text-embedding-3-small"
        self.SUMMARY_MODEL = "gpt-4o-mini"
        self.EMBEDDING_DIMENSIONS = 1536
        
        # Processing settings - NOW CONFIGURABLE
        self.MAX_SUMMARY_WORDS = summary_words  # Can be set to 500 or 1000
        self.MAX_DOCS_PER_TOPIC = 50
        self.CHUNK_SIZE = 500
        
        # API Keys from config.yaml
        self.OPENAI_API_KEY = self.config_data.get('openai_api_key')
        self.PINECONE_API_KEY = self.config_data.get('pinecone_api_key')
        
        # Validate required keys
        self.validate_config()
    
    def load_config(self, config_file: str) -> dict:
        """Load configuration from YAML file"""
        try:
            with open(config_file, 'r') as f:
                config = yaml.safe_load(f)
            logger.info(f"Loaded configuration from {config_file}")
            return config
        except FileNotFoundError:
            logger.error(f"Configuration file {config_file} not found")
            raise
        except yaml.YAMLError as e:
            logger.error(f"Error parsing YAML file: {e}")
            raise
    
    def validate_config(self):
        """Validate that required API keys are present"""
        missing_keys = []
        
        if not self.OPENAI_API_KEY:
            missing_keys.append('openai_api_key')
        
        if not self.PINECONE_API_KEY:
            missing_keys.append('pinecone_api_key')
        
        if missing_keys:
            logger.error(f"Missing required API keys in config.yaml: {missing_keys}")
            raise ValueError(f"Missing required API keys: {', '.join(missing_keys)}")
        
        logger.info("All required API keys found in configuration")

class TopicSummarizer:
    def __init__(self, config_file="config.yaml", summary_words=500, run_name=None):
        self.config = Config(config_file, summary_words)
        self.run_name = run_name or f"{summary_words}word_run_{datetime.now().strftime('%Y%m%d_%H%M%S')}"
        self.s3_client = None
        self.openai_client = None
        self.pinecone_client = None
        self.pinecone_index = None
        self.embedder = None
        self.topic_model = None
        self.clustered_vectors = None
        
        logger.info(f"Initialized TopicSummarizer for {summary_words}-word summaries, run: {self.run_name}")
        
    def initialize_clients(self):
        """Initialize all external service clients - UPDATED"""
        try:
            logger.info("Initializing clients...")
            
            # Initialize S3 client
            self.s3_client = boto3.client("s3")
            logger.info("S3 client initialized")
            
            # Initialize OpenAI client
            self.openai_client = OpenAI(api_key=self.config.OPENAI_API_KEY)
            logger.info("OpenAI client initialized")
            
            # Test OpenAI connection
            try:
                test_response = self.openai_client.chat.completions.create(
                    model="gpt-3.5-turbo",
                    messages=[{"role": "user", "content": "Hello"}],
                    max_tokens=5
                )
                logger.info("OpenAI API connection test successful")
            except Exception as e:
                logger.error(f"OpenAI API connection test failed: {e}")
                raise
            
            # Initialize Pinecone client
            self.pinecone_client = Pinecone(api_key=self.config.PINECONE_API_KEY)
            self.pinecone_index = self.pinecone_client.Index(self.config.PINECONE_INDEX)
            logger.info("Pinecone client initialized")
            
            # REMOVED: sentence transformer initialization since we're using OpenAI
            # self.embedder = SentenceTransformer(self.config.EMBEDDING_MODEL)
            
            logger.info("All clients initialized successfully")
        except Exception as e:
            logger.error(f"Failed to initialize clients: {e}")
            raise
    
    def generate_embedding(self, text: str) -> List[float]:
        """Generate 1536-dimensional embedding using OpenAI"""
        try:
            response = self.openai_client.embeddings.create(
                model=self.config.EMBEDDING_MODEL,
                input=text,
                dimensions=self.config.EMBEDDING_DIMENSIONS
            )
            embedding = response.data[0].embedding
            
            # Verify dimensions
            if len(embedding) != self.config.EMBEDDING_DIMENSIONS:
                raise ValueError(f"Expected {self.config.EMBEDDING_DIMENSIONS} dimensions, got {len(embedding)}")
                
            return embedding
            
        except Exception as e:
            logger.error(f"Failed to generate embedding: {e}")
            raise
    
    def load_data(self):
        """Load clustered data and BERTopic model"""
        try:
            logger.info("Loading clustered vectors...")
            with open(self.config.CLUSTERED_VECTORS_PATH, "rb") as f:
                self.clustered_vectors = pickle.load(f)
            logger.info(f"Loaded clustered vectors: {len(self.clustered_vectors)} items")
            
            if isinstance(self.clustered_vectors, pd.DataFrame):
                logger.info(f"DataFrame shape: {self.clustered_vectors.shape}, columns: {list(self.clustered_vectors.columns)}")
            else:
                logger.info(f"Data type: {type(self.clustered_vectors)}")

            self.load_topic_model()
        except Exception as e:
            logger.error(f"Error loading data: {e}")
            raise

    def load_topic_model(self):
        """Load BERTopic model - NOTE: This may need adjustment"""
        try:
            logger.info(f"Loading BERTopic model from: {self.config.TOPIC_MODEL_PATH}")
            
            # WARNING: If your BERTopic model was trained with all-MiniLM-L6-v2 (384 dims),
            # you might need to retrain it or handle the dimension mismatch
            
            # For now, load without embedding model to avoid conflicts
            self.topic_model = BERTopic.load(self.config.TOPIC_MODEL_PATH)
            topics = self.topic_model.get_topics()
            logger.info(f"Loaded BERTopic model with {len(topics)} topics")
            
            # Log warning about potential embedding model mismatch
            logger.warning("BERTopic model may have been trained with different embedding dimensions. "
                         "Summary embeddings will use 1536 dimensions, but topic model may use different dimensions.")
            
        except Exception as e:
            logger.error(f"Error loading BERTopic model: {e}")
            raise

    def group_documents_by_topic(self) -> Dict[int, List[str]]:
        """Group documents by their topic ID"""
        logger.info("Grouping documents by topic...")
        topic_to_docs = {}

        if isinstance(self.clustered_vectors, pd.DataFrame):
            df = self.clustered_vectors
            if 'topic_id' not in df.columns or 'text' not in df.columns:
                raise ValueError("clustered_vectors must include 'topic_id' and 'text'")
            for topic_id, group in df.dropna(subset=['topic_id', 'text']).groupby('topic_id'):
                if topic_id == -1:  # Skip noise cluster
                    continue
                topic_to_docs[int(topic_id)] = group['text'].tolist()
        else:
            for item in self.clustered_vectors:
                if not isinstance(item, dict): 
                    continue
                topic_id = item.get("topic_id")
                text = item.get("text")
                if topic_id is not None and text and topic_id != -1:
                    topic_to_docs.setdefault(topic_id, []).append(text)

        logger.info(f"Grouped documents into {len(topic_to_docs)} topics")
        return topic_to_docs

    def generate_summary(self, topic_id: int, docs: List[str]) -> str:
        """Generate summary for a single topic"""
        try:
            combined_text = "\n\n".join(docs[:self.config.MAX_DOCS_PER_TOPIC])
            
            logger.info(f"Generating {self.config.MAX_SUMMARY_WORDS}-word summary for topic {topic_id} with {len(docs)} documents")
            logger.info(f"Combined text length: {len(combined_text)} characters")
            
            prompt = (
                f"You are a helpful assistant. Write a comprehensive and detailed {self.config.MAX_SUMMARY_WORDS}-word summary "
                f"of the key themes, insights, and patterns found in the following documents. "
                f"Focus on capturing the main ideas, important details, and any nuanced perspectives present in the text.\n\n"
                f"Documents:\n{combined_text}\n\n"
                f"Please provide a {self.config.MAX_SUMMARY_WORDS}-word summary:"
            )
            
            # Adjust max_tokens based on summary length
            max_tokens = int(self.config.MAX_SUMMARY_WORDS * 1.5)  # Allow some buffer
            
            response = self.openai_client.chat.completions.create(
                model=self.config.SUMMARY_MODEL,
                messages=[{"role": "user", "content": prompt}],
                temperature=0.5,
                max_tokens=max_tokens
            )
            
            summary = response.choices[0].message.content.strip()
            logger.info(f"Successfully generated summary for topic {topic_id}: {len(summary)} characters")
            return summary
            
        except Exception as e:
            logger.error(f"Failed to generate summary for topic {topic_id}: {e}")
            raise
    
    def save_to_s3(self, topic_id: int, summary_text: str):
        """Save summary to S3"""
        try:
            s3_key = f"{self.config.S3_PREFIX}{self.run_name}/topic_{topic_id}.json"
            
            summary_data = {
                "topic_id": topic_id,
                "summary_text": summary_text,
                "source": "BERTopic",
                "run_name": self.run_name,
                "summary_word_target": self.config.MAX_SUMMARY_WORDS,
                "timestamp": datetime.now().isoformat(),
                "model_used": self.config.SUMMARY_MODEL
            }
            
            self.s3_client.put_object(
                Bucket=self.config.S3_BUCKET,
                Key=s3_key,
                Body=json.dumps(summary_data, indent=2),
                ContentType="application/json"
            )
            logger.info(f"Saved topic {topic_id} to S3: {s3_key}")
            
        except Exception as e:
            logger.error(f"Failed to save topic {topic_id} to S3: {e}")
            raise
    
    def save_to_pinecone(self, topic_id: int, summary_text: str):
        """Save summary chunks to Pinecone - UPDATED FOR 1536 DIMS"""
        try:
            chunks = [summary_text[i:i+self.config.CHUNK_SIZE] 
                     for i in range(0, len(summary_text), self.config.CHUNK_SIZE)]
            
            vectors_to_upsert = []
            for i, chunk in enumerate(chunks):
                # Use OpenAI embedding instead of sentence transformer
                embedding = self.generate_embedding(chunk)
                vector_id = f"summary-{self.run_name}-{topic_id}-{i}"
                
                metadata = {
                    "type": "summary",
                    "topic_id": str(topic_id),
                    "chunk_id": i,
                    "source": "BERTopic",
                    "summary_quality": "v1.0",
                    "run_name": self.run_name,
                    "summary_word_target": self.config.MAX_SUMMARY_WORDS,
                    "timestamp": datetime.now().isoformat(),
                    "model_used": self.config.SUMMARY_MODEL,
                    "embedding_model": self.config.EMBEDDING_MODEL,
                    "embedding_dimensions": self.config.EMBEDDING_DIMENSIONS
                }
                
                vectors_to_upsert.append((vector_id, embedding, metadata))
            
            # Batch upsert for efficiency
            self.pinecone_index.upsert(vectors=vectors_to_upsert)
            logger.info(f"Saved {len(chunks)} chunks for topic {topic_id} to Pinecone with {self.config.EMBEDDING_DIMENSIONS} dimensions")
            
        except Exception as e:
            logger.error(f"Failed to save topic {topic_id} to Pinecone: {e}")
            raise
    
    def save_summaries_locally(self, summaries: Dict[int, str]):
        """Save summaries to local file for backup"""
        try:
            local_dir = f"rizzbot_data/summaries_{self.run_name}"
            os.makedirs(local_dir, exist_ok=True)
            
            # Save individual summaries
            for topic_id, summary_text in summaries.items():
                filename = os.path.join(local_dir, f"topic_{topic_id}.txt")
                with open(filename, 'w', encoding='utf-8') as f:
                    f.write(f"Topic ID: {topic_id}\n")
                    f.write(f"Run Name: {self.run_name}\n")
                    f.write(f"Target Words: {self.config.MAX_SUMMARY_WORDS}\n")
                    f.write(f"Timestamp: {datetime.now().isoformat()}\n")
                    f.write(f"Model: {self.config.SUMMARY_MODEL}\n")
                    f.write("-" * 50 + "\n")
                    f.write(summary_text)
            
            # Save consolidated file
            consolidated_file = os.path.join(local_dir, "all_summaries.json")
            with open(consolidated_file, 'w', encoding='utf-8') as f:
                summary_data = {
                    "run_name": self.run_name,
                    "summary_word_target": self.config.MAX_SUMMARY_WORDS,
                    "timestamp": datetime.now().isoformat(),
                    "model_used": self.config.SUMMARY_MODEL,
                    "total_topics": len(summaries),
                    "summaries": summaries
                }
                json.dump(summary_data, f, indent=2, ensure_ascii=False)
            
            logger.info(f"Saved {len(summaries)} summaries locally in {local_dir}")
            
        except Exception as e:
            logger.error(f"Failed to save summaries locally: {e}")
            raise
    
    def run_summarization(self) -> Dict[int, str]:
        """Run summarization for all topics - FIXED VERSION"""
        topic_to_docs = self.group_documents_by_topic()
        summaries = {}
        failed_topics = []

        logger.info(f"Starting {self.config.MAX_SUMMARY_WORDS}-word summarization for {len(topic_to_docs)} topics...")

        for topic_id in tqdm(topic_to_docs, desc=f"Generating {self.config.MAX_SUMMARY_WORDS}-word summaries"):
            try:
                docs = topic_to_docs[topic_id]
                summary = self.generate_summary(topic_id, docs)
                summaries[topic_id] = summary
                
                # Save to external services
                self.save_to_s3(topic_id, summary)
                self.save_to_pinecone(topic_id, summary)
                
            except Exception as e:
                logger.error(f"Topic {topic_id} failed: {e}")
                failed_topics.append(topic_id)

        # Save local backup
        self.save_summaries_locally(summaries)
        
        logger.info(f"Summarization completed for {self.run_name}")
        logger.info(f"Successful: {len(summaries)} | Failed: {len(failed_topics)}")
        
        if failed_topics:
            logger.warning(f"Failed topics: {failed_topics}")

        return summaries

    def run(self) -> Dict[int, str]:
        """Main execution method - SIMPLIFIED"""
        try:
            logger.info(f"Starting TopicSummarizer run: {self.run_name}")
            self.initialize_clients()
            self.load_data()
            summaries = self.run_summarization()
            logger.info(f"Run {self.run_name} completed successfully with {len(summaries)} summaries")
            return summaries
        except Exception as e:
            logger.error(f"Fatal error during execution: {e}")
            raise


def main():
    """Main entry point with support for different word counts"""
    try:
        # Run 500-word summaries
        print("=== Running 500-word summaries ===")
        summarizer_500 = TopicSummarizer("config.yaml", summary_words=500, run_name="500word_summaries")
        results_500 = summarizer_500.run()
        print(f"500-word summaries completed: {len(results_500)} summaries generated")
        
        # Run 1000-word summaries  
        print("\n=== Running 1000-word summaries ===")
        summarizer_1000 = TopicSummarizer("config.yaml", summary_words=1000, run_name="1000word_summaries")
        results_1000 = summarizer_1000.run()
        print(f"1000-word summaries completed: {len(results_1000)} summaries generated")
        
        # Final summary
        print(f"\n=== FINAL RESULTS ===")
        print(f"500-word summaries: {len(results_500)}")
        print(f"1000-word summaries: {len(results_1000)}")
        print(f"Total summaries generated: {len(results_500) + len(results_1000)}")
        
    except Exception as e:
        logger.error(f"Script failed: {e}")
        raise

def run_single_batch(word_count=500):
    """Helper function to run just one batch of summaries"""
    try:
        run_name = f"{word_count}word_summaries_{datetime.now().strftime('%Y%m%d_%H%M%S')}"
        summarizer = TopicSummarizer("config.yaml", summary_words=word_count, run_name=run_name)
        results = summarizer.run()
        
        print(f"\n=== RESULTS ===")
        print(f"Generated {len(results)} summaries of {word_count} words each")
        return results
        
    except Exception as e:
        logger.error(f"Script failed: {e}")
        raise

if __name__ == "__main__":
    # You can choose to run both or just one:
    
    # Option 1: Run both 500 and 1000 word summaries
    # main()
    
    # Option 2: Run just 1000-word summaries
    run_single_batch(word_count=1000)
    
    # Option 3: Run just 500-word summaries  
    # run_single_batch(word_count=500)
# Out:
# 2025-07-01 18:18:29,953 - INFO - Loaded configuration from config.yaml
# 2025-07-01 18:18:29,954 - INFO - All required API keys found in configuration
# 2025-07-01 18:18:29,955 - INFO - Initialized TopicSummarizer for 1000-word summaries, run: 1000word_summaries_20250701_181829
# 2025-07-01 18:18:29,956 - INFO - Starting TopicSummarizer run: 1000word_summaries_20250701_181829
# 2025-07-01 18:18:29,957 - INFO - Initializing clients...
# 2025-07-01 18:18:29,963 - INFO - S3 client initialized
# 2025-07-01 18:18:30,263 - INFO - OpenAI client initialized
# 2025-07-01 18:18:31,222 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 18:18:31,227 - INFO - OpenAI API connection test successful
# 2025-07-01 18:18:31,229 - INFO - Pinecone client initialized
# 2025-07-01 18:18:31,230 - INFO - All clients initialized successfully
# 2025-07-01 18:18:31,231 - INFO - Loading clustered vectors...
# 2025-07-01 18:18:31,274 - INFO - Loaded clustered vectors: 470 items
# 2025-07-01 18:18:31,275 - INFO - DataFrame shape: (470, 9), columns: ['id', 'text', 'embedding', 'cluster', 'x', 'y', 'topic_num', 'topic_id', 'topic_score']
# 2025-07-01 18:18:31,276 - INFO - Loading BERTopic model from: rizzbot_data/bertopic_model
# 2025-07-01 18:18:31,300 - INFO - Loaded BERTopic model with 53 topics
# 2025-07-01 18:18:31,301 - WARNING - BERTopic model may have been trained with different embedding dimensions. Summary embeddings will use 1536 dimensions, but topic model may use different dimensions.
# 2025-07-01 18:18:31,302 - INFO - Grouping documents by topic...
# 2025-07-01 18:18:31,306 - INFO - Grouped documents into 42 topics
# 2025-07-01 18:18:31,306 - INFO - Starting 1000-word summarization for 42 topics...
# Generating 1000-word summaries:   0%|          | 0/42 [00:00<?, ?it/s]2025-07-01 18:18:31,309 - INFO - Generating 1000-word summary for topic 0 with 128 documents
# 2025-07-01 18:18:31,310 - INFO - Combined text length: 148799 characters
# 2025-07-01 18:18:50,766 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 18:18:50,769 - INFO - Successfully generated summary for topic 0: 5351 characters
# 2025-07-01 18:18:51,336 - INFO - Saved topic 0 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_0.json
# 2025-07-01 18:18:51,830 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:18:52,039 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:18:52,525 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:18:52,955 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:18:53,256 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:18:53,597 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:18:53,853 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:18:54,073 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:18:54,599 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:18:55,027 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:18:55,659 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:18:57,140 - INFO - Saved 11 chunks for topic 0 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:   2%|▏         | 1/42 [00:25<17:39, 25.83s/it]2025-07-01 18:18:57,144 - INFO - Generating 1000-word summary for topic 2 with 49 documents
# 2025-07-01 18:18:57,145 - INFO - Combined text length: 96888 characters
# 2025-07-01 18:19:17,550 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 18:19:17,553 - INFO - Successfully generated summary for topic 2: 5584 characters
# 2025-07-01 18:19:18,127 - INFO - Saved topic 2 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_2.json
# 2025-07-01 18:19:18,347 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:19:18,547 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:19:18,758 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:19:18,988 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:19:19,381 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:19:19,593 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:19:19,827 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:19:20,016 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:19:20,242 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:19:20,443 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:19:20,672 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:19:20,896 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:19:21,241 - INFO - Saved 12 chunks for topic 2 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:   5%|▍         | 2/42 [00:49<16:32, 24.81s/it]2025-07-01 18:19:21,244 - INFO - Generating 1000-word summary for topic 6 with 20 documents
# 2025-07-01 18:19:21,245 - INFO - Combined text length: 72145 characters
# 2025-07-01 18:19:35,394 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 18:19:35,399 - INFO - Successfully generated summary for topic 6: 4926 characters
# 2025-07-01 18:19:35,999 - INFO - Saved topic 6 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_6.json
# 2025-07-01 18:19:37,258 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:19:37,491 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:19:37,853 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:19:38,117 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:19:38,330 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:19:38,553 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:19:38,733 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:19:38,958 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:19:39,316 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:19:39,598 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:19:39,832 - INFO - Saved 10 chunks for topic 6 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:   7%|▋         | 3/42 [01:08<14:16, 21.97s/it]2025-07-01 18:19:39,834 - INFO - Generating 1000-word summary for topic 7 with 17 documents
# 2025-07-01 18:19:39,835 - INFO - Combined text length: 26879 characters
# 2025-07-01 18:20:01,317 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 18:20:01,321 - INFO - Successfully generated summary for topic 7: 6038 characters
# 2025-07-01 18:20:01,939 - INFO - Saved topic 7 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_7.json
# 2025-07-01 18:20:02,301 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:02,521 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:02,740 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:02,975 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:03,183 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:03,435 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:03,673 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:04,079 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:04,342 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:04,572 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:04,823 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:05,217 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:05,768 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:06,030 - INFO - Saved 13 chunks for topic 7 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:  10%|▉         | 4/42 [01:34<14:58, 23.64s/it]2025-07-01 18:20:06,031 - INFO - Generating 1000-word summary for topic 9 with 15 documents
# 2025-07-01 18:20:06,031 - INFO - Combined text length: 52523 characters
# 2025-07-01 18:20:25,383 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 18:20:25,387 - INFO - Successfully generated summary for topic 9: 5684 characters
# 2025-07-01 18:20:25,939 - INFO - Saved topic 9 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_9.json
# 2025-07-01 18:20:26,119 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:26,465 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:26,923 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:27,811 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:28,291 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:29,200 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:29,461 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:29,823 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:30,060 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:30,284 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:30,583 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:30,782 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:31,040 - INFO - Saved 12 chunks for topic 9 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:  12%|█▏        | 5/42 [01:59<14:52, 24.13s/it]2025-07-01 18:20:31,043 - INFO - Generating 1000-word summary for topic 10 with 14 documents
# 2025-07-01 18:20:31,044 - INFO - Combined text length: 51003 characters
# 2025-07-01 18:20:50,430 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 18:20:50,434 - INFO - Successfully generated summary for topic 10: 5763 characters
# 2025-07-01 18:20:51,000 - INFO - Saved topic 10 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_10.json
# 2025-07-01 18:20:51,199 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:51,641 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:51,931 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:52,128 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:52,321 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:52,520 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:52,772 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:52,961 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:53,160 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:53,375 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:53,741 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:54,118 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:20:54,402 - INFO - Saved 12 chunks for topic 10 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:  14%|█▍        | 6/42 [02:23<14:19, 23.87s/it]2025-07-01 18:20:54,406 - INFO - Generating 1000-word summary for topic 11 with 13 documents
# 2025-07-01 18:20:54,407 - INFO - Combined text length: 2284 characters
# 2025-07-01 18:21:06,719 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 18:21:06,723 - INFO - Successfully generated summary for topic 11: 5364 characters
# 2025-07-01 18:21:07,329 - INFO - Saved topic 11 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_11.json
# 2025-07-01 18:21:07,844 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:08,039 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:08,422 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:08,620 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:09,227 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:09,437 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:09,673 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:09,864 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:10,147 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:10,675 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:10,883 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:11,215 - INFO - Saved 11 chunks for topic 11 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:  17%|█▋        | 7/42 [02:39<12:34, 21.56s/it]2025-07-01 18:21:11,217 - INFO - Generating 1000-word summary for topic 12 with 11 documents
# 2025-07-01 18:21:11,218 - INFO - Combined text length: 4576 characters
# 2025-07-01 18:21:32,257 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 18:21:32,261 - INFO - Successfully generated summary for topic 12: 5563 characters
# 2025-07-01 18:21:32,849 - INFO - Saved topic 12 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_12.json
# 2025-07-01 18:21:33,107 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:33,301 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:33,566 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:33,778 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:33,964 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:34,174 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:34,434 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:34,644 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:34,870 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:35,097 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:35,691 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:35,939 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:36,210 - INFO - Saved 12 chunks for topic 12 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:  19%|█▉        | 8/42 [03:04<12:50, 22.66s/it]2025-07-01 18:21:36,213 - INFO - Generating 1000-word summary for topic 15 with 10 documents
# 2025-07-01 18:21:36,215 - INFO - Combined text length: 37106 characters
# 2025-07-01 18:21:51,946 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 18:21:51,947 - INFO - Successfully generated summary for topic 15: 5904 characters
# 2025-07-01 18:21:52,550 - INFO - Saved topic 15 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_15.json
# 2025-07-01 18:21:52,849 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:53,273 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:53,993 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:54,560 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:54,743 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:54,946 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:55,257 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:55,727 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:55,930 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:56,116 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:56,363 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:56,631 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:21:56,861 - INFO - Saved 12 chunks for topic 15 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:  21%|██▏       | 9/42 [03:25<12:06, 22.03s/it]2025-07-01 18:21:56,863 - INFO - Generating 1000-word summary for topic 16 with 10 documents
# 2025-07-01 18:21:56,864 - INFO - Combined text length: 35004 characters
# 2025-07-01 18:22:14,449 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 18:22:14,452 - INFO - Successfully generated summary for topic 16: 5658 characters
# 2025-07-01 18:22:14,985 - INFO - Saved topic 16 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_16.json
# 2025-07-01 18:22:15,233 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:15,462 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:15,707 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:15,942 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:16,250 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:16,537 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:16,713 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:17,231 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:17,654 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:17,948 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:18,191 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:18,459 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:18,757 - INFO - Saved 12 chunks for topic 16 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:  24%|██▍       | 10/42 [03:47<11:43, 21.99s/it]2025-07-01 18:22:18,760 - INFO - Generating 1000-word summary for topic 17 with 9 documents
# 2025-07-01 18:22:18,761 - INFO - Combined text length: 31686 characters
# 2025-07-01 18:22:36,788 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 18:22:36,793 - INFO - Successfully generated summary for topic 17: 5561 characters
# 2025-07-01 18:22:37,353 - INFO - Saved topic 17 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_17.json
# 2025-07-01 18:22:37,547 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:37,811 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:38,040 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:39,265 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:39,466 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:39,685 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:39,884 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:40,144 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:40,373 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:40,565 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:40,795 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:41,060 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:41,368 - INFO - Saved 12 chunks for topic 17 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:  26%|██▌       | 11/42 [04:10<11:27, 22.18s/it]2025-07-01 18:22:41,371 - INFO - Generating 1000-word summary for topic 18 with 9 documents
# 2025-07-01 18:22:41,372 - INFO - Combined text length: 19626 characters
# 2025-07-01 18:22:55,542 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 18:22:55,545 - INFO - Successfully generated summary for topic 18: 4492 characters
# 2025-07-01 18:22:56,089 - INFO - Saved topic 18 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_18.json
# 2025-07-01 18:22:56,293 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:56,521 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:56,701 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:56,892 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:57,085 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:57,482 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:57,727 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:57,983 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:58,330 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:22:58,575 - INFO - Saved 9 chunks for topic 18 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:  29%|██▊       | 12/42 [04:27<10:19, 20.67s/it]2025-07-01 18:22:58,577 - INFO - Generating 1000-word summary for topic 19 with 9 documents
# 2025-07-01 18:22:58,579 - INFO - Combined text length: 29048 characters
# 2025-07-01 18:23:15,541 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 18:23:15,553 - INFO - Successfully generated summary for topic 19: 5466 characters
# 2025-07-01 18:23:16,078 - INFO - Saved topic 19 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_19.json
# 2025-07-01 18:23:16,463 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:16,654 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:16,878 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:17,333 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:17,610 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:17,908 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:18,084 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:18,316 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:18,551 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:19,051 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:19,270 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:19,556 - INFO - Saved 11 chunks for topic 19 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:  31%|███       | 13/42 [04:48<10:02, 20.76s/it]2025-07-01 18:23:19,558 - INFO - Generating 1000-word summary for topic 20 with 8 documents
# 2025-07-01 18:23:19,560 - INFO - Combined text length: 25502 characters
# 2025-07-01 18:23:35,506 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 18:23:35,508 - INFO - Successfully generated summary for topic 20: 5300 characters
# 2025-07-01 18:23:36,103 - INFO - Saved topic 20 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_20.json
# 2025-07-01 18:23:36,408 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:36,677 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:37,027 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:37,555 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:37,824 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:38,062 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:38,266 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:38,475 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:38,665 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:38,861 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:39,183 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:39,435 - INFO - Saved 11 chunks for topic 20 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:  33%|███▎      | 14/42 [05:08<09:33, 20.49s/it]2025-07-01 18:23:39,437 - INFO - Generating 1000-word summary for topic 21 with 7 documents
# 2025-07-01 18:23:39,438 - INFO - Combined text length: 25894 characters
# 2025-07-01 18:23:54,563 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 18:23:54,566 - INFO - Successfully generated summary for topic 21: 6191 characters
# 2025-07-01 18:23:55,121 - INFO - Saved topic 21 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_21.json
# 2025-07-01 18:23:55,407 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:55,595 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:55,842 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:56,052 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:56,236 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:56,497 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:56,933 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:57,126 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:57,430 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:57,784 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:58,131 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:58,333 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:58,610 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:23:58,907 - INFO - Saved 13 chunks for topic 21 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:  36%|███▌      | 15/42 [05:27<09:05, 20.19s/it]2025-07-01 18:23:58,910 - INFO - Generating 1000-word summary for topic 22 with 7 documents
# 2025-07-01 18:23:58,910 - INFO - Combined text length: 24499 characters
# 2025-07-01 18:24:13,559 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 18:24:13,564 - INFO - Successfully generated summary for topic 22: 5488 characters
# 2025-07-01 18:24:14,101 - INFO - Saved topic 22 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_22.json
# 2025-07-01 18:24:14,320 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:14,544 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:14,823 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:15,379 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:15,904 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:16,167 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:16,359 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:16,577 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:16,801 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:17,256 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:17,475 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:17,703 - INFO - Saved 11 chunks for topic 22 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:  38%|███▊      | 16/42 [05:46<08:33, 19.77s/it]2025-07-01 18:24:17,706 - INFO - Generating 1000-word summary for topic 23 with 7 documents
# 2025-07-01 18:24:17,707 - INFO - Combined text length: 27036 characters
# 2025-07-01 18:24:33,645 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 18:24:33,648 - INFO - Successfully generated summary for topic 23: 5945 characters
# 2025-07-01 18:24:34,228 - INFO - Saved topic 23 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_23.json
# 2025-07-01 18:24:34,411 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:34,606 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:34,837 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:36,070 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:36,281 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:36,653 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:36,917 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:37,171 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:37,710 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:38,154 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:38,441 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:38,662 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:38,903 - INFO - Saved 12 chunks for topic 23 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:  40%|████      | 17/42 [06:07<08:24, 20.20s/it]2025-07-01 18:24:38,905 - INFO - Generating 1000-word summary for topic 24 with 7 documents
# 2025-07-01 18:24:38,906 - INFO - Combined text length: 26183 characters
# 2025-07-01 18:24:56,963 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 18:24:56,977 - INFO - Successfully generated summary for topic 24: 6166 characters
# 2025-07-01 18:24:57,547 - INFO - Saved topic 24 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_24.json
# 2025-07-01 18:24:57,802 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:57,998 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:58,223 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:58,416 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:58,631 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:59,117 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:59,367 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:59,665 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:24:59,896 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:25:01,196 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:25:01,459 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:25:01,671 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:25:01,946 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:25:02,198 - INFO - Saved 13 chunks for topic 24 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:  43%|████▎     | 18/42 [06:30<08:27, 21.13s/it]2025-07-01 18:25:02,201 - INFO - Generating 1000-word summary for topic 25 with 7 documents
# 2025-07-01 18:25:02,202 - INFO - Combined text length: 3703 characters
# 2025-07-01 18:25:18,555 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 18:25:18,557 - INFO - Successfully generated summary for topic 25: 6014 characters
# 2025-07-01 18:25:19,115 - INFO - Saved topic 25 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_25.json
# 2025-07-01 18:25:20,172 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:25:20,375 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:25:20,577 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:25:21,034 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:25:21,300 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:25:21,547 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:25:21,776 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:25:21,998 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:25:22,226 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:25:22,415 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:25:22,593 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:25:22,784 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:25:23,025 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:25:23,287 - INFO - Saved 13 chunks for topic 25 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:  45%|████▌     | 19/42 [06:51<08:05, 21.12s/it]2025-07-01 18:25:23,290 - INFO - Generating 1000-word summary for topic 27 with 7 documents
# 2025-07-01 18:25:23,291 - INFO - Combined text length: 24579 characters
# 2025-07-01 18:25:37,549 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 18:25:37,551 - INFO - Successfully generated summary for topic 27: 5043 characters
# 2025-07-01 18:25:38,111 - INFO - Saved topic 27 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_27.json
# 2025-07-01 18:25:38,385 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:25:38,658 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:25:39,185 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:25:39,374 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:25:39,581 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:25:39,965 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:25:40,176 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:25:40,749 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:25:40,998 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:25:41,203 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:25:41,684 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:25:41,970 - INFO - Saved 11 chunks for topic 27 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:  48%|████▊     | 20/42 [07:10<07:28, 20.39s/it]2025-07-01 18:25:41,972 - INFO - Generating 1000-word summary for topic 28 with 7 documents
# 2025-07-01 18:25:41,973 - INFO - Combined text length: 25944 characters
# 2025-07-01 18:26:09,398 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 18:26:09,403 - INFO - Successfully generated summary for topic 28: 5712 characters
# 2025-07-01 18:26:09,981 - INFO - Saved topic 28 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_28.json
# 2025-07-01 18:26:10,238 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:10,717 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:10,932 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:11,366 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:11,606 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:11,883 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:12,152 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:12,595 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:12,874 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:13,165 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:13,594 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:13,806 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:14,136 - INFO - Saved 12 chunks for topic 28 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:  50%|█████     | 21/42 [07:42<08:22, 23.92s/it]2025-07-01 18:26:14,139 - INFO - Generating 1000-word summary for topic 29 with 7 documents
# 2025-07-01 18:26:14,140 - INFO - Combined text length: 23172 characters
# 2025-07-01 18:26:31,922 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 18:26:31,929 - INFO - Successfully generated summary for topic 29: 6107 characters
# 2025-07-01 18:26:32,512 - INFO - Saved topic 29 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_29.json
# 2025-07-01 18:26:32,686 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:32,895 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:33,224 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:33,528 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:33,744 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:34,050 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:34,266 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:34,460 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:34,728 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:34,920 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:35,247 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:35,455 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:35,648 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:36,019 - INFO - Saved 13 chunks for topic 29 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:  52%|█████▏    | 22/42 [08:04<07:46, 23.31s/it]2025-07-01 18:26:36,020 - INFO - Generating 1000-word summary for topic 30 with 6 documents
# 2025-07-01 18:26:36,021 - INFO - Combined text length: 21403 characters
# 2025-07-01 18:26:55,086 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 18:26:55,088 - INFO - Successfully generated summary for topic 30: 6302 characters
# 2025-07-01 18:26:55,630 - INFO - Saved topic 30 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_30.json
# 2025-07-01 18:26:55,935 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:56,119 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:56,739 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:57,295 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:57,505 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:57,850 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:58,054 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:58,422 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:58,705 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:58,916 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:26:59,812 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:27:00,027 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:27:00,250 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:27:00,550 - INFO - Saved 13 chunks for topic 30 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:  55%|█████▍    | 23/42 [08:29<07:29, 23.68s/it]2025-07-01 18:27:00,551 - INFO - Generating 1000-word summary for topic 31 with 6 documents
# 2025-07-01 18:27:00,551 - INFO - Combined text length: 22190 characters
# 2025-07-01 18:27:20,554 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 18:27:20,561 - INFO - Successfully generated summary for topic 31: 5318 characters
# 2025-07-01 18:27:21,138 - INFO - Saved topic 31 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_31.json
# 2025-07-01 18:27:21,339 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:27:21,525 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:27:21,799 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:27:22,111 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:27:22,375 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:27:22,548 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:27:22,990 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:27:23,204 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:27:23,388 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:27:23,651 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:27:23,872 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 18:27:24,124 - INFO - Saved 11 chunks for topic 31 to Pinecone with 1536 dimensions
# ...
# 2025-07-01 19:29:13,986 - INFO - Combined text length: 14056 characters
# 2025-07-01 19:29:31,724 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 19:29:31,728 - INFO - Successfully generated summary for topic 43: 5529 characters
# 2025-07-01 19:29:32,300 - INFO - Saved topic 43 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_43.json
# 2025-07-01 19:29:32,503 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:29:33,528 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:29:33,969 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:29:34,219 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:29:34,461 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:29:38,374 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:29:38,638 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:29:38,866 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:29:39,058 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:29:39,255 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:29:39,469 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:29:39,648 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:29:40,167 - INFO - Saved 12 chunks for topic 43 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:  83%|████████▎ | 35/42 [1:11:08<23:12, 198.91s/it]2025-07-01 19:29:40,170 - INFO - Generating 1000-word summary for topic 44 with 4 documents
# 2025-07-01 19:29:40,171 - INFO - Combined text length: 14551 characters
# 2025-07-01 19:30:06,352 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 19:30:06,354 - INFO - Successfully generated summary for topic 44: 4729 characters
# 2025-07-01 19:30:06,903 - INFO - Saved topic 44 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_44.json
# 2025-07-01 19:30:07,445 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:07,647 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:07,864 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:08,513 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:08,706 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:08,931 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:09,346 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:09,556 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:09,760 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:10,212 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:10,516 - INFO - Saved 10 chunks for topic 44 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:  86%|████████▌ | 36/42 [1:11:39<14:50, 148.34s/it]2025-07-01 19:30:10,518 - INFO - Generating 1000-word summary for topic 45 with 4 documents
# 2025-07-01 19:30:10,520 - INFO - Combined text length: 15135 characters
# 2025-07-01 19:30:27,850 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 19:30:27,857 - INFO - Successfully generated summary for topic 45: 5627 characters
# 2025-07-01 19:30:28,379 - INFO - Saved topic 45 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_45.json
# 2025-07-01 19:30:28,618 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:28,899 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:29,105 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:29,310 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:29,531 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:29,721 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:29,928 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:30,132 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:30,587 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:30,834 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:31,036 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:31,484 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:31,740 - INFO - Saved 12 chunks for topic 45 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:  88%|████████▊ | 37/42 [1:12:00<09:11, 110.21s/it]2025-07-01 19:30:31,744 - INFO - Generating 1000-word summary for topic 46 with 4 documents
# 2025-07-01 19:30:31,745 - INFO - Combined text length: 3862 characters
# 2025-07-01 19:30:45,638 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 19:30:45,647 - INFO - Successfully generated summary for topic 46: 5455 characters
# 2025-07-01 19:30:46,218 - INFO - Saved topic 46 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_46.json
# 2025-07-01 19:30:46,408 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:46,663 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:46,854 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:47,353 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:47,670 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:47,891 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:48,189 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:48,383 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:48,603 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:49,032 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:49,273 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:30:49,533 - INFO - Saved 11 chunks for topic 46 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:  90%|█████████ | 38/42 [1:12:18<05:29, 82.48s/it] 2025-07-01 19:30:49,536 - INFO - Generating 1000-word summary for topic 48 with 4 documents
# 2025-07-01 19:30:49,539 - INFO - Combined text length: 14459 characters
# 2025-07-01 19:31:05,017 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 19:31:05,021 - INFO - Successfully generated summary for topic 48: 5018 characters
# 2025-07-01 19:31:05,577 - INFO - Saved topic 48 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_48.json
# 2025-07-01 19:31:05,803 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:06,145 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:06,356 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:06,569 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:06,774 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:07,011 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:07,265 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:07,477 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:07,677 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:07,923 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:08,119 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:08,371 - INFO - Saved 11 chunks for topic 48 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:  93%|█████████▎| 39/42 [1:12:37<03:10, 63.39s/it]2025-07-01 19:31:08,373 - INFO - Generating 1000-word summary for topic 49 with 4 documents
# 2025-07-01 19:31:08,373 - INFO - Combined text length: 13768 characters
# 2025-07-01 19:31:23,833 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 19:31:23,838 - INFO - Successfully generated summary for topic 49: 6220 characters
# 2025-07-01 19:31:24,382 - INFO - Saved topic 49 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_49.json
# 2025-07-01 19:31:24,654 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:24,858 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:25,094 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:25,412 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:25,731 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:25,949 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:26,350 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:26,562 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:26,747 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:26,956 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:27,451 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:27,898 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:28,173 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:28,534 - INFO - Saved 13 chunks for topic 49 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:  95%|█████████▌| 40/42 [1:12:57<01:40, 50.42s/it]2025-07-01 19:31:28,536 - INFO - Generating 1000-word summary for topic 50 with 4 documents
# 2025-07-01 19:31:28,537 - INFO - Combined text length: 14539 characters
# 2025-07-01 19:31:50,112 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 19:31:50,119 - INFO - Successfully generated summary for topic 50: 6076 characters
# 2025-07-01 19:31:50,710 - INFO - Saved topic 50 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_50.json
# 2025-07-01 19:31:51,005 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:51,842 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:52,097 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:52,354 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:52,599 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:52,939 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:53,226 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:53,423 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:53,621 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:53,830 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:54,091 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:54,263 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:54,512 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:31:54,806 - INFO - Saved 13 chunks for topic 50 to Pinecone with 1536 dimensions
# Generating 1000-word summaries:  98%|█████████▊| 41/42 [1:13:23<00:43, 43.18s/it]2025-07-01 19:31:54,809 - INFO - Generating 1000-word summary for topic 51 with 3 documents
# 2025-07-01 19:31:54,810 - INFO - Combined text length: 9001 characters
# 2025-07-01 19:32:14,966 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-07-01 19:32:14,971 - INFO - Successfully generated summary for topic 51: 6412 characters
# 2025-07-01 19:32:15,523 - INFO - Saved topic 51 to S3: rizzbot/Summaries/1000word_summaries_20250701_181829/topic_51.json
# 2025-07-01 19:32:15,737 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:32:15,948 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:32:16,148 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:32:16,403 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:32:17,273 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:32:17,685 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:32:17,897 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:32:18,159 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:32:18,423 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:32:18,671 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:32:18,902 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:32:19,120 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:32:19,606 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-07-01 19:32:19,887 - INFO - Saved 13 chunks for topic 51 to Pinecone with 1536 dimensions
# Generating 1000-word summaries: 100%|██████████| 42/42 [1:13:48<00:00, 105.44s/it]
# 2025-07-01 19:32:19,925 - INFO - Saved 42 summaries locally in rizzbot_data/summaries_1000word_summaries_20250701_181829
# 2025-07-01 19:32:19,926 - INFO - Summarization completed for 1000word_summaries_20250701_181829
# 2025-07-01 19:32:19,927 - INFO - Successful: 42 | Failed: 0
# 2025-07-01 19:32:19,928 - INFO - Run 1000word_summaries_20250701_181829 completed successfully with 42 summaries
# === RESULTS ===
# Generated 42 summaries of 1000 words each
