# %% [markdown]
# This notebook sets up the Agentic system.
# The simplified flow of the system is as follows:
# User gives input question as a prompt -> Preprocess the question via prompt tuning -> do a semantic search query over the summary database  ->
#
# (branch 1): is the answer in a summary (or spread over multiple)? -> use the summary/summaries to generate summary answer -> output answer to user
#
# (branch 2): is the answer not in a summary? -> semantic search query the entire dataset for the answer -> retrieve the relevant chunks -> generate summary of the relevant results -> output answer to user

# %%
# rizzbot_agentic.py with logging and conversation memory

import os
import numpy as np
from typing import List, Dict, Optional, Tuple
from datetime import datetime
from langchain.schema.runnable import RunnableLambda, RunnableBranch
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain.agents import AgentExecutor, Tool, initialize_agent, AgentType
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_pinecone import PineconeVectorStore
from pinecone import Pinecone
from langsmith import Client
from langchain.retrievers.multi_query import MultiQueryRetriever


class ConversationMemory:
    """Manages conversation history and user context"""
    
    def __init__(self, max_history_length: int = 10):
        self.max_history_length = max_history_length
        self.conversation_history: List[Dict] = []
        self.user_profile: Dict = {
            'social_goals': [],
            'challenges_mentioned': [],
            'advice_given': [],
            'preferences': {},
            'success_stories': [],
            'first_interaction': None
        }
    
    def add_interaction(self, question: str, response: str, sources: List[str] = None):
        """Add a new interaction to the conversation history"""
        interaction = {
            'timestamp': datetime.now().isoformat(),
            'question': question,
            'response': response,
            'sources': sources or []
        }
        
        self.conversation_history.append(interaction)
        
        # Keep only the last N interactions
        if len(self.conversation_history) > self.max_history_length:
            self.conversation_history = self.conversation_history[-self.max_history_length:]
        
        # Update user profile
        self._update_user_profile(question, response)
        
        # Set first interaction timestamp
        if self.user_profile['first_interaction'] is None:
            self.user_profile['first_interaction'] = interaction['timestamp']
    
    def _update_user_profile(self, question: str, response: str):
        """Extract insights from the interaction to update user profile"""
        question_lower = question.lower()
        
        # Identify social goals
        goal_keywords = {
            'dating': ['dating', 'date', 'romantic', 'girlfriend', 'boyfriend'],
            'networking': ['networking', 'professional', 'work', 'career', 'colleague'],
            'public_speaking': ['presentation', 'public speaking', 'speech', 'audience'],
            'confidence': ['confidence', 'shy', 'nervous', 'anxious'],
            'conversation': ['conversation', 'small talk', 'chat', 'talking']
        }
        
        for goal, keywords in goal_keywords.items():
            if any(keyword in question_lower for keyword in keywords):
                if goal not in self.user_profile['social_goals']:
                    self.user_profile['social_goals'].append(goal)
        
        # Identify challenges mentioned
        challenge_keywords = ['struggle', 'difficult', 'hard', 'problem', 'issue', 'challenge']
        if any(keyword in question_lower for keyword in challenge_keywords):
            # Extract the context around challenge keywords
            for keyword in challenge_keywords:
                if keyword in question_lower:
                    challenge_context = question[:100]  # Keep first 100 chars as context
                    if challenge_context not in self.user_profile['challenges_mentioned']:
                        self.user_profile['challenges_mentioned'].append(challenge_context)
        
        # Track advice topics given
        advice_keywords = ['advice', 'tip', 'suggestion', 'recommend', 'try']
        if any(keyword in response.lower() for keyword in advice_keywords):
            # Simple extraction - in a real implementation, you might use NLP to extract key topics
            self.user_profile['advice_given'].append({
                'timestamp': datetime.now().isoformat(),
                'topic': question[:50] + "...",  # Truncated question as topic
                'response_snippet': response[:100] + "..."
            })
    
    def get_conversation_context(self) -> str:
        """Get formatted conversation context for the prompt"""
        if not self.conversation_history:
            return ""
        
        context_parts = []
        
        # Add user profile summary
        if self.user_profile['social_goals']:
            context_parts.append(f"User's social goals: {', '.join(self.user_profile['social_goals'])}")
        
        if self.user_profile['challenges_mentioned']:
            recent_challenges = self.user_profile['challenges_mentioned'][-2:]  # Last 2 challenges
            context_parts.append(f"Recent challenges mentioned: {'; '.join(recent_challenges)}")
        
        # Add recent conversation history
        if len(self.conversation_history) > 1:
            context_parts.append("Recent conversation:")
            for interaction in self.conversation_history[-3:]:  # Last 3 interactions
                context_parts.append(f"Q: {interaction['question']}")
                context_parts.append(f"A: {interaction['response'][:100]}...")
        
        return "\n".join(context_parts)
    
    def get_user_profile_summary(self) -> str:
        """Get a summary of the user's profile"""
        profile_parts = []
        
        if self.user_profile['social_goals']:
            profile_parts.append(f"Goals: {', '.join(self.user_profile['social_goals'])}")
        
        if self.user_profile['challenges_mentioned']:
            profile_parts.append(f"Challenges: {len(self.user_profile['challenges_mentioned'])} mentioned")
        
        if self.user_profile['advice_given']:
            profile_parts.append(f"Advice given: {len(self.user_profile['advice_given'])} topics")
        
        if self.user_profile['first_interaction']:
            profile_parts.append(f"First interaction: {self.user_profile['first_interaction']}")
        
        return "; ".join(profile_parts) if profile_parts else "New user"
    
    def is_follow_up_question(self, question: str) -> bool:
        """Check if the current question is a follow-up to previous conversation"""
        if not self.conversation_history:
            return False
        
        follow_up_indicators = [
            'what about', 'how about', 'and if', 'but what', 'also', 'additionally',
            'follow up', 'more on', 'expand on', 'tell me more', 'what else'
        ]
        
        question_lower = question.lower()
        return any(indicator in question_lower for indicator in follow_up_indicators)


class Rizzbot:
    def __init__(self, session_id: str = None):
        print("[INIT] Starting Rizzbot initialization...")
        self.session_id = session_id or f"session_{datetime.now().strftime('%Y%m%d_%H%M%S')}"
        self.memory = ConversationMemory()
        print(f"[INIT] Session ID: {self.session_id}")
        
        _ = self._load_env()
        self.similarity_threshold = 0.3
        self.top_k = 3
        self.summary_threshold = 3  # Stop after finding this many docs in summaries

        os.environ["LANGCHAIN_TRACING_V2"] = "true"
        os.environ["LANGCHAIN_PROJECT"] = "rizzbot"
        print("[ENV] Environment variables set.")

        self.client = Client()

        self.main_llm = ChatOpenAI(model="gpt-4o", temperature=0.25)
        print("[LLM] Main LLM (gpt-4o) initialized.")

        self.expand_llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0.6)
        print("[LLM] Expansion LLM (gpt-3.5-turbo) initialized.")

        self.embeddings = OpenAIEmbeddings(model="text-embedding-3-small")
        print("[Embeddings] OpenAI embeddings initialized.")

        self.pc = Pinecone(api_key=os.getenv("PINECONE_API_KEY"))
        print("[Pinecone] Pinecone client initialized.")

        self.summaries_vectorstore = PineconeVectorStore(
            index_name="rizzbot-summaries-full-text",
            embedding=self.embeddings,
            text_key="full_text"
        )
        print("[VectorStore] Summaries vector store initialized.")

        self.full_vectorstore = PineconeVectorStore(
            index_name="rizzbot", embedding=self.embeddings, text_key="full_text"
        )
        print("[VectorStore] Full vector store initialized.")

        self.no_answer_response = "Sorry bro, I couldn't find enough info to answer that confidently."

        # Updated prompt template to include conversation context
        self.base_prompt_template = ChatPromptTemplate.from_template("""
        You are a charisma and personal development expert helping someone improve their social skills.

        User Profile: {user_profile}
        Conversation Context: {conversation_context}
        
        Current Question: {question}
        Relevant Content: {content}

        Instructions:
        1. Consider the user's profile and conversation history when answering
        2. If this is a follow-up question, reference previous interactions appropriately
        3. Provide actionable, specific advice based on the context and user's goals
        4. Use examples when possible, tailored to the user's specific situation
        5. Keep the tone encouraging and supportive
        6. If the question cannot be answered from the vectorstore content, respond: "Sorry bro, I couldn't find enough info in my database to answer that confidently."
        7. Build on previous advice when relevant
        8. At the end of your response, include a "Sources:" section listing the document sources used

        Response:
        """)

        self._build_agent_chain()
        print("[INIT] Rizzbot initialized and ready.")

    def _load_env(self):
        from dotenv import load_dotenv, find_dotenv
        print("[ENV] Loading environment variables from .env file...")
        return load_dotenv(find_dotenv())

    def _embed_question(self, question: str) -> List[float]:
        print(f"[Embed] Embedding question: {question}")
        result = self.embeddings.embed_query(question)
        print(f"[Embed] Embedding result length: {len(result)}")
        return result

    def _cosine_similarity(self, vec1, vec2):
        vec1, vec2 = np.array(vec1), np.array(vec2)
        return np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))

    def _filter_by_similarity(self, query_embedding, docs, threshold):
        filtered = []
        sources = []

        for doc in docs:
            try:
                doc_embedding = self.embeddings.embed_query(doc.page_content)
                sim = self._cosine_similarity(query_embedding, doc_embedding)
                print(f"[Similarity] Score: {sim:.4f} | Text: {doc.page_content[:80]}...")

                if sim >= threshold:
                    filtered.append(doc)
                    # Extract source information from document metadata
                    source_info = self._extract_source_info(doc)
                    sources.append(source_info)
            except Exception as e:
                print(f"[Similarity] Failed to embed doc: {e}")

        return filtered, sources

    def _extract_source_info(self, doc) -> str:
        """Extract source information from document metadata"""
        if hasattr(doc, 'metadata') and doc.metadata:
            # Try to get source information from metadata
            source = doc.metadata.get('source', 'Unknown source')
            title = doc.metadata.get('title', '')
            if title:
                return f"{title} ({source})"
            else:
                return source
        else:
            # Fallback to truncated content as identifier
            return f"Document: {doc.page_content[:50]}..."

    def _hybrid_query_search(self, question: str) -> Tuple[List[str], List[str]]:
        print(f"[Search:Hybrid] Embedding question...")
        question_embedding = self._embed_question(question)
        combined_results = []
        all_sources = []

        # First, try summaries vectorstore
        print(f"[Search:Hybrid] Trying summaries vectorstore...")
        try:
            retriever = MultiQueryRetriever.from_llm(
                retriever=self.summaries_vectorstore.as_retriever(search_kwargs={"k": self.top_k}),
                llm=self.expand_llm
            )
            docs = retriever.invoke(question)
            filtered, sources = self._filter_by_similarity(question_embedding, docs, self.similarity_threshold)
            print(f"[Search:Hybrid] {len(filtered)} docs passed threshold in summaries.")
            
            if len(filtered) > self.summary_threshold:
                print(f"[Search:Hybrid] Found {len(filtered)} docs in summaries (>{self.summary_threshold}), skipping full search.")
                combined_results.extend([doc.page_content for doc in filtered])
                all_sources.extend(sources)
                return combined_results, all_sources
            else:
                combined_results.extend([doc.page_content for doc in filtered])
                all_sources.extend(sources)
        except Exception as e:
            print(f"[Search:Hybrid] Retrieval failed for summaries: {e}")

        # If we didn't find enough in summaries, search full vectorstore
        print(f"[Search:Hybrid] Trying full vectorstore...")
        try:
            retriever = MultiQueryRetriever.from_llm(
                retriever=self.full_vectorstore.as_retriever(search_kwargs={"k": self.top_k}),
                llm=self.expand_llm
            )
            docs = retriever.invoke(question)
            filtered, sources = self._filter_by_similarity(question_embedding, docs, self.similarity_threshold)
            print(f"[Search:Hybrid] {len(filtered)} docs passed threshold in full.")
            combined_results.extend([doc.page_content for doc in filtered])
            all_sources.extend(sources)
        except Exception as e:
            print(f"[Search:Hybrid] Retrieval failed for full: {e}")

        return combined_results, all_sources

    def _build_agent_chain(self):
        print("[Chain] Building agent chain...")

        def hybrid_search_with_sources(question):
            # Handle both string and dict inputs for robustness
            if isinstance(question, dict):
                question = question.get("question", "")
            results, sources = self._hybrid_query_search(question)
            if results:
                content = "\n\n".join(results)
                return content
            else:
                return self.no_answer_response
    
        self.agent_chain = (
            {
                "question": lambda q: q,
                "content": hybrid_search_with_sources,
                "conversation_context": lambda q: self.memory.get_conversation_context(),
                "user_profile": lambda q: self.memory.get_user_profile_summary(),
            }
            | self.base_prompt_template
            | self.main_llm
            | StrOutputParser()
        )

        print("[Chain] Agent chain constructed.")

    def answer_question(self, question: str) -> str:
        print(f"[Answer] Received question: {question}")
        print(f"[Memory] Is follow-up: {self.memory.is_follow_up_question(question)}")
        
        try:
            context, sources = self._hybrid_query_search(question)
            if not context:
                print("[Answer] No relevant documents found. Returning fallback response.")
                response = self.no_answer_response
            else:
                print("[Answer] Relevant context found. Generating response with LLM...")
                response = self.agent_chain.invoke(question)
                print(f"[Answer] Answer generated successfully.")
            
            # Add interaction to memory
            self.memory.add_interaction(question, response, sources)
            print(f"[Memory] Interaction added to memory. Total interactions: {len(self.memory.conversation_history)}")
            
            return response
        except Exception as e:
            print(f"[Answer] Agentic pipeline failed: {e}")
            error_response = self.no_answer_response
            self.memory.add_interaction(question, error_response, [])
            return error_response
    
    def get_conversation_summary(self) -> str:
        """Get a summary of the conversation so far"""
        return self.memory.get_conversation_context()
    
    def get_user_insights(self) -> Dict:
        """Get insights about the user based on conversation history"""
        return self.memory.user_profile
    
    def reset_conversation(self):
        """Reset the conversation memory"""
        self.memory = ConversationMemory()
        print("[Memory] Conversation memory reset.")


# Example usage:
if __name__ == "__main__":
    # Initialize the bot with a session ID
    bot = Rizzbot(session_id="test_session_001")
    
    # Example conversation
    questions = [
        "How do I start a conversation with someone I find attractive?",
        "What if they seem disinterested?",
        "How about at a networking event instead?",
        "I'm really nervous about public speaking. Any tips?"
    ]
    
    for question in questions:
        print(f"\n{'='*50}")
        print(f"User: {question}")
        response = bot.answer_question(question)
        print(f"Bot: {response}")
        print(f"User Profile: {bot.get_user_insights()}")
# Out:
# [INIT] Starting Rizzbot initialization...
# [INIT] Session ID: test_session_001
# [ENV] Loading environment variables from .env file...
# [ENV] Environment variables set.
# [LLM] Main LLM (gpt-4o) initialized.
# [LLM] Expansion LLM (gpt-3.5-turbo) initialized.
# [Embeddings] OpenAI embeddings initialized.
# [Pinecone] Pinecone client initialized.
# [VectorStore] Summaries vector store initialized.
# [VectorStore] Full vector store initialized.
# [Chain] Building agent chain...
# [Chain] Agent chain constructed.
# [INIT] Rizzbot initialized and ready.
#
# ==================================================
# User: How do I start a conversation with someone I find attractive?
# [Answer] Received question: How do I start a conversation with someone I find attractive?
# [Memory] Is follow-up: False
# [Search:Hybrid] Embedding question...
# [Embed] Embedding question: How do I start a conversation with someone I find attractive?
# [Embed] Embedding result length: 1536
# [Search:Hybrid] Trying summaries vectorstore...
# [Similarity] Score: 0.3390 | Text: Topic ID: 44
# Run Name: 1000word_summaries_20250702_132026
# Target Words: 1000
# Tim...
# [Similarity] Score: 0.3699 | Text: Topic ID: 22
# Run Name: 1000word_summaries_20250702_132026
# Target Words: 1000
# Tim...
# [Similarity] Score: 0.2985 | Text: Topic ID: 1
# Run Name: 1000word_summaries_20250702_132026
# Target Words: 1000
# Time...
# [Search:Hybrid] 2 docs passed threshold in summaries.
# [Search:Hybrid] Trying full vectorstore...
# [Similarity] Score: 0.0930 | Text:  is getting a redesign so I'm very, very proud to share it with you today. So I ...
# [Similarity] Score: 0.1953 | Text:  can click the link on the screen to join today or to go ahead and learn more. E...
# [Similarity] Score: 0.1026 | Text:  Either way, I hope you enjoyed this video and I look forward to seeing you in t...
# [Similarity] Score: 0.1380 | Text: , you can give yourself a full refund from right inside the program. If you want...
# [Similarity] Score: 0.2002 | Text:  the program. If you want to see if Charisma University is right for you, click ...
# [Similarity] Score: 0.1931 | Text:  That's kind of the point of these types of arguments and the instinct here is t...
# [Similarity] Score: 0.1716 | Text: 'm going to link to those below. For now, know that in a debate setting, a well-...
# [Search:Hybrid] 0 docs passed threshold in full.
# [Answer] Relevant context found. Generating response with LLM...
# [Search:Hybrid] Embedding question...
# [Embed] Embedding question: How do I start a conversation with someone I find attractive?
# [Embed] Embedding result length: 1536
# [Search:Hybrid] Trying summaries vectorstore...
# [Similarity] Score: 0.3390 | Text: Topic ID: 44
# Run Name: 1000word_summaries_20250702_132026
# Target Words: 1000
# Tim...
# [Similarity] Score: 0.3698 | Text: Topic ID: 22
# Run Name: 1000word_summaries_20250702_132026
# Target Words: 1000
# Tim...
# [Similarity] Score: 0.2491 | Text: Topic ID: 29
# Run Name: 1000word_summaries_20250702_132026
# Target Words: 1000
# Tim...
# [Similarity] Score: 0.2985 | Text: Topic ID: 1
# Run Name: 1000word_summaries_20250702_132026
# Target Words: 1000
# Time...
# [Search:Hybrid] 2 docs passed threshold in summaries.
# [Search:Hybrid] Trying full vectorstore...
# [Similarity] Score: 0.0931 | Text:  is getting a redesign so I'm very, very proud to share it with you today. So I ...
# [Similarity] Score: 0.1954 | Text:  can click the link on the screen to join today or to go ahead and learn more. E...
# [Similarity] Score: 0.1027 | Text:  Either way, I hope you enjoyed this video and I look forward to seeing you in t...
# [Similarity] Score: 0.3221 | Text: . And I was like, oh, you know, I was like running on some rooftops. And then li...
# [Similarity] Score: 0.1381 | Text: , you can give yourself a full refund from right inside the program. If you want...
# [Similarity] Score: 0.3178 | Text:  Van Helsing, it just really... Van Helsing got terrible reviews and the fact he...
# [Similarity] Score: 0.2002 | Text:  the program. If you want to see if Charisma University is right for you, click ...
# [Similarity] Score: 0.1931 | Text:  That's kind of the point of these types of arguments and the instinct here is t...
# [Similarity] Score: 0.1716 | Text: 'm going to link to those below. For now, know that in a debate setting, a well-...
# [Search:Hybrid] 2 docs passed threshold in full.
# [Answer] Answer generated successfully.
# [Memory] Interaction added to memory. Total interactions: 1
# Bot: Starting a conversation with someone you find attractive can be both exciting and nerve-wracking. Here are some actionable strategies to help you initiate a conversation with confidence and authenticity:
#
# ### 1. **Be Authentic and Confident**
# - **Authenticity**: It's important to be yourself. Trying to be someone you're not can come across as disingenuous. Show genuine interest in the person you're speaking to, and let your natural personality shine through.
# - **Confidence**: Confidence is attractive. Approach the conversation with a positive mindset, believing that you have something valuable to offer. Remember, the goal is to connect, not to impress.
#
# ### 2. **Use Effective Conversation Starters**
# - **Self-Introduction**: A simple and effective way to start is by introducing yourself. For example, "Hi, I don't think we've met yet. I'm [Your Name]."
# - **Observational Comments**: Make a comment about your surroundings or something you notice about them. For instance, "I couldn't help but notice your [unique item or feature]. It’s really interesting!"
# - **Tourist Technique**: Pretend to be new to the area and ask for recommendations. This can lead to a natural and engaging conversation.
#
# ### 3. **Incorporate Humor and Playfulness**
# - **Humor**: Use humor to make the interaction light-hearted. You can start with a playful comment or a funny observation. For example, if you're at a coffee shop, you might say, "I think I’ve officially reached my caffeine limit for the day. How about you?"
# - **Playful Teasing**: Light teasing can create a fun dynamic. Just ensure it’s good-natured and not at the expense of the other person.
#
# ### 4. **Make Genuine Compliments**
# - **Compliments**: Offer a sincere compliment. It could be about their style, smile, or something unique you’ve noticed. Ensure it’s specific and genuine, like "I really like your style; it’s very unique."
#
# ### 5. **Ask Open-Ended Questions**
# - **Engage with Questions**: Ask questions that require more than a yes or no answer. This encourages the other person to share more about themselves. For example, "What’s been the highlight of your day so far?"
#
# ### 6. **Create a Safe and Comfortable Environment**
# - **Non-Judgmental Attitude**: Approach the conversation with an open mind and avoid making judgments. This helps the other person feel comfortable and more willing to open up.
#
# ### 7. **Use Body Language to Your Advantage**
# - **Relaxed Posture**: Maintain a relaxed and open posture. Avoid crossing your arms or leaning in too aggressively, as this can create discomfort.
# - **Eye Contact**: Make eye contact to show interest and attentiveness, but don’t overdo it to the point of making the other person uncomfortable.
#
# ### 8. **Practice and Build Habits**
# - **Start Small**: Practice these techniques in low-pressure environments, like with friends or in casual settings, to build your confidence.
# - **Focus on One Technique**: If you feel overwhelmed, focus on mastering one technique at a time, such as using humor or making genuine compliments.
#
# By incorporating these strategies, you can enhance your social skills and make your interactions more engaging and enjoyable. Remember, the key is to be genuine, confident, and open to the possibilities that each conversation can bring.
#
# ### Sources:
# - Document discussing the intricacies of flirting and initiating conversations.
# - Video analysis of Craig Ferguson's conversational style.
# User Profile: {'social_goals': ['conversation'], 'challenges_mentioned': [], 'advice_given': [{'timestamp': '2025-07-03T20:19:02.053909', 'topic': 'How do I start a conversation with someone I find ...', 'response_snippet': 'Starting a conversation with someone you find attractive can be both exciting and nerve-wracking. He...'}], 'preferences': {}, 'success_stories': [], 'first_interaction': '2025-07-03T20:19:02.053909'}
#
# ==================================================
# User: What if they seem disinterested?
# [Answer] Received question: What if they seem disinterested?
# [Memory] Is follow-up: False
# [Search:Hybrid] Embedding question...
# [Embed] Embedding question: What if they seem disinterested?
# [Embed] Embedding result length: 1536
# [Search:Hybrid] Trying summaries vectorstore...
# [Similarity] Score: 0.2825 | Text: Topic ID: 37
# Run Name: 1000word_summaries_20250702_132026
# Target Words: 1000
# Tim...
# [Similarity] Score: 0.2754 | Text: Topic ID: 44
# Run Name: 1000word_summaries_20250702_132026
# Target Words: 1000
# Tim...
# [Similarity] Score: 0.2380 | Text: Topic ID: 22
# Run Name: 1000word_summaries_20250702_132026
# Target Words: 1000
# Tim...
# [Similarity] Score: 0.2569 | Text: Topic ID: 32
# Run Name: 1000word_summaries_20250702_132026
# Target Words: 1000
# Tim...
# [Search:Hybrid] 0 docs passed threshold in summaries.
# [Search:Hybrid] Trying full vectorstore...
# [Similarity] Score: 0.2270 | Text: Something bad is going on with young men. It's bad for them, and it's bad for th...
# [Similarity] Score: 0.2108 | Text:  genre 50 years ago had its own issues. Man talk. What I'm saying is that if Rea...
# [Similarity] Score: 0.1005 | Text:  harsh environment and seems to be, nobody is really taking advantage of her, wh...
# [Similarity] Score: 0.1882 | Text: . You can see this in our world today. Many people right now hate the uber-wealt...
# [Similarity] Score: 0.1603 | Text: Four and a half years ago, I made a video predicting that long-shot candidate Tr...
# [Similarity] Score: 0.1389 | Text:  Dream speech. Let freedom ring from the curvaceous slopes of California. But no...
# [Search:Hybrid] 0 docs passed threshold in full.
# [Answer] No relevant documents found. Returning fallback response.
# [Memory] Interaction added to memory. Total interactions: 2
# Bot: Sorry bro, I couldn't find enough info to answer that confidently.
# User Profile: {'social_goals': ['conversation'], 'challenges_mentioned': [], 'advice_given': [{'timestamp': '2025-07-03T20:19:02.053909', 'topic': 'How do I start a conversation with someone I find ...', 'response_snippet': 'Starting a conversation with someone you find attractive can be both exciting and nerve-wracking. He...'}], 'preferences': {}, 'success_stories': [], 'first_interaction': '2025-07-03T20:19:02.053909'}
#
# ==================================================
# User: How about at a networking event instead?
# [Answer] Received question: How about at a networking event instead?
# [Memory] Is follow-up: True
# [Search:Hybrid] Embedding question...
# [Embed] Embedding question: How about at a networking event instead?
# [Embed] Embedding result length: 1536
# [Search:Hybrid] Trying summaries vectorstore...
# [Similarity] Score: 0.2483 | Text: Topic ID: 1
# Run Name: 1000word_summaries_20250702_132026
# Target Words: 1000
# Time...
# [Similarity] Score: 0.2264 | Text: Topic ID: 44
# Run Name: 1000word_summaries_20250702_132026
# Target Words: 1000
# Tim...
# [Similarity] Score: 0.1964 | Text: Topic ID: 30
# Run Name: 1000word_summaries_20250702_132026
# Target Words: 1000
# Tim...
# [Similarity] Score: 0.2521 | Text: Topic ID: 48
# Run Name: 1000word_summaries_20250702_132026
# Target Words: 1000
# Tim...
# [Similarity] Score: 0.2462 | Text: Topic ID: 43
# Run Name: 1000word_summaries_20250702_132026
# Target Words: 1000
# Tim...
# [Search:Hybrid] 0 docs passed threshold in summaries.
# [Search:Hybrid] Trying full vectorstore...
# [Similarity] Score: 0.0789 | Text:  is getting a redesign so I'm very, very proud to share it with you today. So I ...
# [Similarity] Score: 0.2076 | Text:  yada, and they get that rubber stamp over the weekend. And then there's the per...
# [Similarity] Score: 0.1393 | Text:  it really started. If you want more on similar topics of success, check out the...
# [Similarity] Score: 0.1857 | Text:  This is obviously just for fun. If you liked it and you want me to do other TV ...
# [Similarity] Score: 0.1991 | Text: 't retract it. You can't persuade. You have to go, I apologize. There's two dire...
# [Search:Hybrid] 0 docs passed threshold in full.
# [Answer] No relevant documents found. Returning fallback response.
# [Memory] Interaction added to memory. Total interactions: 3
# Bot: Sorry bro, I couldn't find enough info to answer that confidently.
# User Profile: {'social_goals': ['conversation', 'networking'], 'challenges_mentioned': [], 'advice_given': [{'timestamp': '2025-07-03T20:19:02.053909', 'topic': 'How do I start a conversation with someone I find ...', 'response_snippet': 'Starting a conversation with someone you find attractive can be both exciting and nerve-wracking. He...'}], 'preferences': {}, 'success_stories': [], 'first_interaction': '2025-07-03T20:19:02.053909'}
#
# ==================================================
# User: I'm really nervous about public speaking. Any tips?
# [Answer] Received question: I'm really nervous about public speaking. Any tips?
# [Memory] Is follow-up: False
# [Search:Hybrid] Embedding question...
# [Embed] Embedding question: I'm really nervous about public speaking. Any tips?
# [Embed] Embedding result length: 1536
# [Search:Hybrid] Trying summaries vectorstore...
# [Similarity] Score: 0.3320 | Text: Topic ID: 43
# Run Name: 1000word_summaries_20250702_132026
# Target Words: 1000
# Tim...
# [Similarity] Score: 0.3486 | Text: Topic ID: 48
# Run Name: 1000word_summaries_20250702_132026
# Target Words: 1000
# Tim...
# [Similarity] Score: 0.3134 | Text: Topic ID: 1
# Run Name: 1000word_summaries_20250702_132026
# Target Words: 1000
# Time...
# [Similarity] Score: 0.2814 | Text: Topic ID: 17
# Run Name: 1000word_summaries_20250702_132026
# Target Words: 1000
# Tim...
# [Similarity] Score: 0.1995 | Text: Topic ID: 9
# Run Name: 1000word_summaries_20250702_132026
# Target Words: 1000
# Time...
# [Search:Hybrid] 3 docs passed threshold in summaries.
# [Search:Hybrid] Trying full vectorstore...
# [Similarity] Score: 0.2366 | Text:  good skill. I believe in marriage more than anybody. In fact, I believe in marr...
# [Similarity] Score: 0.2717 | Text: 't retract it. You can't persuade. You have to go, I apologize. There's two dire...
# [Similarity] Score: 0.2456 | Text: Bill Burr is one of the most popular comedians alive today, despite having said ...
# [Similarity] Score: 0.2941 | Text:  When I left this job, I actually improved my relationship with the people there...
# [Similarity] Score: 0.1244 | Text:  is getting a redesign so I'm very, very proud to share it with you today. So I ...
# [Search:Hybrid] 0 docs passed threshold in full.
# [Answer] Relevant context found. Generating response with LLM...
# [Search:Hybrid] Embedding question...
# [Embed] Embedding question: I'm really nervous about public speaking. Any tips?
# [Embed] Embedding result length: 1536
# [Search:Hybrid] Trying summaries vectorstore...
# [Similarity] Score: 0.3321 | Text: Topic ID: 43
# Run Name: 1000word_summaries_20250702_132026
# Target Words: 1000
# Tim...
# [Similarity] Score: 0.3486 | Text: Topic ID: 48
# Run Name: 1000word_summaries_20250702_132026
# Target Words: 1000
# Tim...
# [Similarity] Score: 0.3135 | Text: Topic ID: 1
# Run Name: 1000word_summaries_20250702_132026
# Target Words: 1000
# Time...
# [Search:Hybrid] 3 docs passed threshold in summaries.
# [Search:Hybrid] Trying full vectorstore...
# [Similarity] Score: 0.2365 | Text:  good skill. I believe in marriage more than anybody. In fact, I believe in marr...
# [Similarity] Score: 0.2716 | Text: 't retract it. You can't persuade. You have to go, I apologize. There's two dire...
# [Similarity] Score: 0.2456 | Text: Bill Burr is one of the most popular comedians alive today, despite having said ...
# [Similarity] Score: 0.0975 | Text:  Charity Water through the link in the description. It's a birthday campaign and...
# [Similarity] Score: 0.1596 | Text: , distance can be very hard, but it taught me an important lesson. If I had simp...
# [Similarity] Score: 0.1243 | Text:  is getting a redesign so I'm very, very proud to share it with you today. So I ...
# [Similarity] Score: 0.0558 | Text:  harsh environment and seems to be, nobody is really taking advantage of her, wh...
# [Search:Hybrid] 0 docs passed threshold in full.
# [Answer] Answer generated successfully.
# [Memory] Interaction added to memory. Total interactions: 4
# Bot: Public speaking can indeed be nerve-wracking, but with the right strategies, you can build confidence and improve your delivery. Here are some tips to help you feel more at ease and make your public speaking engagements more effective:
#
# 1. **Acknowledge Your Nervousness**: It's perfectly normal to feel nervous before speaking in public. Acknowledging this feeling can help you manage it better. Remember, even experienced speakers feel nervous sometimes. Use this energy to fuel your performance.
#
# 2. **Preparation is Key**: The more prepared you are, the more confident you'll feel. Practice your speech multiple times, and if possible, rehearse in front of a small, supportive audience to get feedback. This will help you become familiar with your material and reduce anxiety.
#
# 3. **Use Humor Wisely**: As discussed in the documents, humor can be a powerful tool to connect with your audience and ease tension. Start with a light-hearted comment or a funny anecdote related to your topic. This can help break the ice and make you and your audience feel more comfortable.
#
# 4. **Engage with Your Audience**: Make eye contact, use open body language, and involve your audience by asking questions or encouraging participation. This creates a more interactive and engaging experience, making you appear more confident and approachable.
#
# 5. **Focus on Your Message, Not Yourself**: Shift your focus from how you're being perceived to the message you're delivering. This can help reduce self-consciousness and allow you to communicate more effectively.
#
# 6. **Visualize Success**: Before your speech, take a moment to visualize yourself delivering a successful presentation. Imagine the audience reacting positively and you feeling confident and composed. This mental rehearsal can boost your confidence.
#
# 7. **Embrace Vulnerability**: As mentioned in the documents, showing vulnerability can make you more relatable. If you stumble or forget something, acknowledge it with humor and move on. This shows authenticity and can endear you to your audience.
#
# 8. **Practice Relaxation Techniques**: Deep breathing, meditation, or visualization exercises can help calm your nerves before speaking. Find a technique that works for you and incorporate it into your pre-speech routine.
#
# By incorporating these strategies, you can improve your public speaking skills and feel more confident in front of an audience. Remember, each speaking opportunity is a chance to learn and grow, so embrace the experience and enjoy the process.
#
# Sources:
# - Document discussing the role of humor and vulnerability in social interactions.
# - Document emphasizing the importance of preparation and engagement in communication.
# - Document highlighting the use of humor and storytelling in effective communication.
# User Profile: {'social_goals': ['conversation', 'networking', 'public_speaking', 'confidence'], 'challenges_mentioned': [], 'advice_given': [{'timestamp': '2025-07-03T20:19:02.053909', 'topic': 'How do I start a conversation with someone I find ...', 'response_snippet': 'Starting a conversation with someone you find attractive can be both exciting and nerve-wracking. He...'}, {'timestamp': '2025-07-03T20:19:45.691678', 'topic': "I'm really nervous about public speaking. Any tips...", 'response_snippet': 'Public speaking can indeed be nerve-wracking, but with the right strategies, you can build confidenc...'}], 'preferences': {}, 'success_stories': [], 'first_interaction': '2025-07-03T20:19:02.053909'}

# %%
# Convert test_answers.txt to .csv file
import pandas as pd
def convert_txt_to_csv(txt_file: str, csv_file: str):
    print(f"[Convert] Converting {txt_file} to {csv_file}...")
    with open(txt_file, "r") as f:
        lines = f.readlines()

    data = []
    for i in range(0, len(lines), 3):
        question = lines[i].strip().replace("Question: ", "")
        answer = lines[i + 1].strip().replace("Answer: ", "")
        data.append({"Question": question, "Answer": answer})

    df = pd.DataFrame(data)
    df.to_csv(csv_file, index=False)
    print(f"[Convert] Conversion complete. Saved to {csv_file}.")
convert_txt_to_csv("test_answers.txt", "test_answers.csv")
# Out:
# [Convert] Converting test_answers.txt to test_answers.csv...
# [Convert] Conversion complete. Saved to test_answers.csv.

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate
import json
from dotenv import load_dotenv, find_dotenv
import re
import pandas as pd

_ = load_dotenv(find_dotenv())

open_ai_api_key = os.getenv("OPENAI_API_KEY")

# Initialize evaluator LLM (use a more critical model like gpt-4 if available)
evaluator_llm = ChatOpenAI(model_name="gpt-4", temperature=0, api_key=open_ai_api_key)

# Evaluation criteria prompt
eval_prompt_template = PromptTemplate.from_template("""
You are an expert evaluator of communication advice.

Evaluate the following AI-generated answer based on these criteria (rate each 1-5):
- Helpfulness: Does it help the user improve charisma or social skill?
- Specificity: Is the advice concrete and not generic?
- Tone: Is it encouraging, empathetic, and natural?
- Groundedness: Does it appear based on the context provided?

Return your answer in JSON format like:
{{
  "helpfulness": 4,
  "specificity": 3,
  "tone": 5,
  "groundedness": 2,
  "comment": "Good tone and practical advice, but lacks reference to context."
}}

---

Question: {question}

Context: {context}

AI Answer:
{answer}
""")
def evaluate_responses_from_csv(csv_file: str):
    # Read the CSV file into a DataFrame
    df = pd.read_csv(csv_file)
    results = []

    for idx, row in df.iterrows():
        question = row["Question"]
        answer = row["Answer"]
        context = ""  # Adjust if you have context

        prompt = eval_prompt_template.format(question=question, context=context, answer=answer)
        response = evaluator_llm.predict(prompt)
        try:
            eval_result = json.loads(response)
        except json.JSONDecodeError:
            print("⚠️ Failed to parse response. Raw output:")
            print(response)
            eval_result = {}
        results.append({
            "question": question,
            "answer": answer,
            **eval_result
        })
    return results

# Example usage:
if __name__ == "__main__":
    eval_results = evaluate_responses_from_csv("test_answers.csv")
    df_eval = pd.DataFrame(eval_results)
    print(df_eval)
    df_eval.to_csv("evaluation_results.csv", index=False)
# Out:
#                                              question  \
# 0   I have a presentation tomorrow, how can I impr...
# 1                     1. **Body Language and Space**:
# 2                     2. **Storytelling Techniques**:
# 3            3. **Confidence Through Vulnerability**:
# 4                 4. **Handling Awkward Situations**:
# 5                           5. **Active Engagement**:
# 6   6. **Preparation and Anticipation of Questions**:
# 7   Remember, the key to a successful presentation...
# 8   - Document discussing body language and storyt...
# 9   How can I make a good first impression on a date?
# 10  1. **Be Authentic**: Authenticity is key to ma...
# 11                                                NaN
# 12  4. **Compliment Without Overdoing It**: Compli...
# 13                                                NaN
# 14  7. **Prepare Conversation Starters**: Having a...
# 15                                                NaN
# 16  - Document on authenticity and avoiding excess...
# 17  What are some examples of behaviours that cele...
# 18  1. **Body Language and Space**: Celebrities li...
# 19                                                NaN
# 20  4. **Active Listening and Engagement**: Engagi...
# 21                                                NaN
# 22  7. **Handling Awkward Situations**: Acknowledg...
# 23                                                NaN
# 24                                           Sources:
# 25  - Document exploring Conor McGregor's charisma...
# 26  What can I do to my body language to feel more...
# 27  1. **Take Up Space**: Confidence is often conv...
# 28                                                NaN
# 29  4. **Practice Active Listening**: Engaging wit...
# 30                                                NaN
# 31  By incorporating these strategies into your in...
# 32                                      - Topic ID: 1
# 33                                                NaN
# 34                                                NaN
# 35  2. **Humor and Playfulness**: Incorporate humo...
# 36                                                NaN
# 37  5. **Confidence Through Vulnerability**: Be au...
# 38                                                NaN
# 39                                           Sources:
#
#                                                answer  helpfulness  \
# 0   To improve your presence on stage for your pre...            1
# 1   - Use open and confident body language. Stand ...            4
# 2   - Incorporate storytelling into your presentat...            4
# 3   - Embrace vulnerability to build confidence. A...            5
# 4   - If you encounter any awkward moments during ...            5
# 5   - Engage with your audience by making eye cont...            5
# 6   - Prepare for potential questions or interrupt...            5
# 7                                                 NaN            1
# 8   - Document discussing handling awkward situati...            2
# 9   To make a good first impression on a date, it'...            3
# 10                                                NaN            1
# 11  3. **Use Effective Communication Techniques**:...            4
# 12                                                NaN            1
# 13  6. **Create a Safe and Comfortable Environment...            4
# 14                                                NaN            1
# 15                                           Sources:            1
# 16  - Document on creating a comfortable atmospher...            2
# 17  To answer the question about behaviors that ma...            4
# 18                                                NaN            1
# 19  3. **Teasing and Compliments**: A balance betw...            4
# 20                                                NaN            1
# 21  6. **Confidence Through Vulnerability**: Being...            4
# 22                                                NaN            1
# 23  These behaviors, when adopted, can enhance one...            2
# 24  - Document discussing techniques and habits of...            1
# 25  - Document on learning charisma and personal d...            2
# 26  To feel more confident through your body langu...            2
# 27                                                NaN            1
# 28  3. **Use Eye Contact and Smiling**: Eye contac...            4
# 29                                                NaN            1
# 30  6. **Embrace Vulnerability**: Confidence can a...            4
# 31                                                NaN            1
# 32                                     - Topic ID: 37            1
# 33    Question: How can I connect with people better?            1
# 34  1. **Body Language and Space**: Use open body ...            4
# 35                                                NaN            1
# 36  4. **Storytelling Techniques**: Enhance your c...            4
# 37                                                NaN            1
# 38  By adopting these strategies, you can improve ...            4
# 39                                    - e, c, n, t, o            1
#
#     specificity  tone  groundedness  \
# 0             1     3             1
# 1             4     4             1
# 2             4     4             1
# 3             4     5             3
# 4             4     5             3
# 5             4     4             1
# 6             4     4             1
# 7             1     1             1
# 8             3     3             1
# 9             2     4             1
# 10            1     1             1
# 11            4     4             1
# 12            1     1             1
# 13            4     4             1
# 14            1     1             1
# 15            1     1             1
# 16            3     3             1
# 17            1     3             1
# 18            1     1             1
# 19            4     4             1
# 20            1     1             1
# 21            3     4             1
# 22            1     1             1
# 23            1     3             1
# 24            1     3             1
# 25            1     3             1
# 26            1     3             1
# 27            1     1             1
# 28            5     4             1
# 29            1     1             1
# 30            4     4             1
# 31            1     1             1
# 32            1     1             1
# 33            1     1             1
# 34            4     4             1
# 35            1     1             1
# 36            4     4             1
# 37            1     1             1
# 38            2     4             1
# 39            1     1             1
#
#                                               comment
# 0   The AI response is incomplete and does not pro...
# 1   The advice is helpful and specific, with a goo...
# 2   The advice is helpful and specific, with a goo...
# 3   The advice is helpful and specific, with a goo...
# 4   The advice is helpful and specific, with a pos...
# 5   The advice is helpful and specific, with a pos...
# 6   The advice is very helpful and specific, with ...
# 7   The AI did not provide an answer, so it's impo...
# 8   The AI response does not align with the contex...
# 9   The advice is generally helpful and the tone i...
# 10                  The AI did not provide an answer.
# 11  The advice is helpful and specific, with a pos...
# 12  The AI did not provide an answer, so it's impo...
# 13  The advice is helpful and specific, with a goo...
# 14                  The AI did not provide an answer.
# 15  The AI response is incomplete and provides no ...
# 16  The advice is not helpful or grounded in the c...
# 17  The AI's response is helpful in setting up an ...
# 18  The AI did not provide an answer, so it's impo...
# 19  The advice is helpful and specific, with a goo...
# 20  The AI did not provide an answer, so it's impo...
# 21  The advice is helpful and has a positive tone,...
# 22  The AI did not provide an answer, so it's impo...
# 23  The advice lacks specificity and context. It i...
# 24  The response does not provide any advice or in...
# 25  The response lacks specificity and doesn't pro...
# 26  The answer lacks specific advice and doesn't p...
# 27  The AI did not provide an answer, so it's impo...
# 28  The advice is helpful and very specific, with ...
# 29  The AI did not provide an answer, so it's impo...
# 30  The advice is helpful and specific, with a goo...
# 31  The AI did not provide an answer, so it's impo...
# 32  The AI response does not provide any advice, l...
# 33      The AI did not provide an answer to evaluate.
# 34  The advice is helpful and specific, with a pos...
# 35  The AI did not provide an answer, so it's impo...
# 36  The advice is helpful and specific, with a pos...
# 37  The AI did not provide an answer, so it's impo...
# 38  The advice is helpful and the tone is encourag...
# 39  The response is not helpful, specific, or grou...
